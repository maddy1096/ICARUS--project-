# %%
import pandas as pd

df = pd.read_csv('/content/dataset_sdn.csv')

y = df.iloc[:,-1]
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 104340    0
# 104341    0
# 104342    0
# 104343    0
# 104344    0
# Name: label, Length: 104345, dtype: int64

# %%
X_x = pd.get_dummies(df.Protocol, prefix='Protocol')
X_x
# Out:
#         Protocol_ICMP  Protocol_TCP  Protocol_UDP
# 0                   0             0             1
# 1                   0             0             1
# 2                   0             0             1
# 3                   0             0             1
# 4                   0             0             1
# ...               ...           ...           ...
# 104340              1             0             0
# 104341              1             0             0
# 104342              1             0             0
# 104343              1             0             0
# 104344              1             0             0
#
# [104345 rows x 3 columns]

# %%
df.insert(22,'Protocol_ICMP',X_x['Protocol_ICMP'])
df.insert(23,'Protocol_TCP',X_x['Protocol_TCP'])
df.insert(24,'Protocol_UDP',X_x['Protocol_UDP'])

# %%
df = df.drop(columns=['Protocol'])
df = df.drop(columns=['label'])

# %%
df
# Out:
#            dt  switch        src  ... Protocol_ICMP  Protocol_TCP  Protocol_UDP
# 0       11425       1   10.0.0.1  ...             0             0             1
# 1       11605       1   10.0.0.1  ...             0             0             1
# 2       11425       1   10.0.0.2  ...             0             0             1
# 3       11425       1   10.0.0.2  ...             0             0             1
# 4       11425       1   10.0.0.2  ...             0             0             1
# ...       ...     ...        ...  ...           ...           ...           ...
# 104340   5262       3   10.0.0.5  ...             1             0             0
# 104341   5262       3   10.0.0.5  ...             1             0             0
# 104342   5262       3  10.0.0.11  ...             1             0             0
# 104343   5262       3  10.0.0.11  ...             1             0             0
# 104344   5262       3  10.0.0.11  ...             1             0             0
#
# [104345 rows x 24 columns]

# %%
zz = pd.get_dummies(df.src, prefix='src')
zz
# Out:
#         src_10.0.0.1  src_10.0.0.10  ...  src_10.0.0.8  src_10.0.0.9
# 0                  1              0  ...             0             0
# 1                  1              0  ...             0             0
# 2                  0              0  ...             0             0
# 3                  0              0  ...             0             0
# 4                  0              0  ...             0             0
# ...              ...            ...  ...           ...           ...
# 104340             0              0  ...             0             0
# 104341             0              0  ...             0             0
# 104342             0              0  ...             0             0
# 104343             0              0  ...             0             0
# 104344             0              0  ...             0             0
#
# [104345 rows x 19 columns]

# %%
ff = pd.get_dummies(df.dst, prefix='dst')
ff

final =  pd.concat([ff,zz],axis = 1)
final_df = pd.concat([df,final],axis =1)
final_df = pd.concat([final_df,y],axis = 1)
final_df
# Out:
#            dt  switch        src  ... src_10.0.0.8  src_10.0.0.9  label
# 0       11425       1   10.0.0.1  ...            0             0      0
# 1       11605       1   10.0.0.1  ...            0             0      0
# 2       11425       1   10.0.0.2  ...            0             0      0
# 3       11425       1   10.0.0.2  ...            0             0      0
# 4       11425       1   10.0.0.2  ...            0             0      0
# ...       ...     ...        ...  ...          ...           ...    ...
# 104340   5262       3   10.0.0.5  ...            0             0      0
# 104341   5262       3   10.0.0.5  ...            0             0      0
# 104342   5262       3  10.0.0.11  ...            0             0      0
# 104343   5262       3  10.0.0.11  ...            0             0      0
# 104344   5262       3  10.0.0.11  ...            0             0      0
#
# [104345 rows x 62 columns]

# %%
final_df = final_df.drop(columns=['src','dst'])
final_df
# Out:
#            dt  switch  pktcount  ...  src_10.0.0.8  src_10.0.0.9  label
# 0       11425       1     45304  ...             0             0      0
# 1       11605       1    126395  ...             0             0      0
# 2       11425       1     90333  ...             0             0      0
# 3       11425       1     90333  ...             0             0      0
# 4       11425       1     90333  ...             0             0      0
# ...       ...     ...       ...  ...           ...           ...    ...
# 104340   5262       3        79  ...             0             0      0
# 104341   5262       3        79  ...             0             0      0
# 104342   5262       3        31  ...             0             0      0
# 104343   5262       3        31  ...             0             0      0
# 104344   5262       3        31  ...             0             0      0
#
# [104345 rows x 60 columns]

# %%
final_df.isna().sum()
final_df['rx_kbps'] = final_df['rx_kbps'].fillna(0)
final_df['tot_kbps'] = final_df['tot_kbps'].fillna(0)
final_df = final_df.astype('int64') 
final_df
# Out:
#            dt  switch  pktcount  ...  src_10.0.0.8  src_10.0.0.9  label
# 0       11425       1     45304  ...             0             0      0
# 1       11605       1    126395  ...             0             0      0
# 2       11425       1     90333  ...             0             0      0
# 3       11425       1     90333  ...             0             0      0
# 4       11425       1     90333  ...             0             0      0
# ...       ...     ...       ...  ...           ...           ...    ...
# 104340   5262       3        79  ...             0             0      0
# 104341   5262       3        79  ...             0             0      0
# 104342   5262       3        31  ...             0             0      0
# 104343   5262       3        31  ...             0             0      0
# 104344   5262       3        31  ...             0             0      0
#
# [104345 rows x 60 columns]

# %%
X = final_df.iloc[:,:-1]
y = final_df.iloc[:,-1]
print(X)
print(y)
# Out:
#            dt  switch  pktcount  ...  src_10.0.0.7  src_10.0.0.8  src_10.0.0.9
# 0       11425       1     45304  ...             0             0             0
# 1       11605       1    126395  ...             0             0             0
# 2       11425       1     90333  ...             0             0             0
# 3       11425       1     90333  ...             0             0             0
# 4       11425       1     90333  ...             0             0             0
# ...       ...     ...       ...  ...           ...           ...           ...
# 104340   5262       3        79  ...             0             0             0
# 104341   5262       3        79  ...             0             0             0
# 104342   5262       3        31  ...             0             0             0
# 104343   5262       3        31  ...             0             0             0
# 104344   5262       3        31  ...             0             0             0
#
# [104345 rows x 59 columns]
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 104340    0
# 104341    0
# 104342    0
# 104343    0
# 104344    0
# Name: label, Length: 104345, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=109)

# %%
from sklearn import svm

clf = svm.SVC()
clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import classification_report
target_names = ['0', '1']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.74      0.74     12718
#            1       0.59      0.57      0.58      8151
#
#     accuracy                           0.68     20869
#    macro avg       0.66      0.66      0.66     20869
# weighted avg       0.68      0.68      0.68     20869

# %%
 from sklearn.metrics import accuracy_score

 acc = accuracy_score(y_test, y_pred)
 print(acc)
# Out:
# 0.6766016579615698

# %%
y_pred_train = clf.predict(X_train)

acc_c = accuracy_score(y_train, y_pred_train)
print(acc_c)
# Out:
# 0.6741219033015478

# %%
from sklearn.metrics import roc_curve, auc

n_class = 2

fpr = dict()
tpr = dict()
roc_auc = dict()
y_score = clf.fit(X_train, y_train).decision_function(X_test)
for i in range(n_class):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot of a ROC curve for a specific class
for i in range(n_classes):
    plt.figure()
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-dff7adfb59ec> in <module>()
#       7 roc_auc = dict()
#       8 for i in range(n_class):
# ----> 9     fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
#      10     roc_auc[i] = auc(fpr[i], tpr[i])
#      11
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     904             return self._get_values(key)
#     905
# --> 906         return self._get_with(key)
#     907
#     908     def _get_with(self, key):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _get_with(self, key)
#     919             )
#     920         elif isinstance(key, tuple):
# --> 921             return self._get_values_tuple(key)
#     922
#     923         elif not is_list_like(key):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _get_values_tuple(self, key)
#     954
#     955         if not isinstance(self.index, MultiIndex):
# --> 956             raise KeyError("key of type tuple not found and not a MultiIndex")
#     957
#     958         # If key is contained, would have returned by now
#
# KeyError: 'key of type tuple not found and not a MultiIndex'
